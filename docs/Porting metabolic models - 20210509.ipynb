# %% [markdown]
# # Porting genome scale metabolic models for metabolomics
#
# - to make formats compatible to mummichog
# - to link to a common compound table
# - from compound table, we generated predicted mass peaks based on formula
#
# As mummichog 3 is under development, treat this as part of development.
#
# **Use cobra to parse SBML models whereas applicable**
#
# Not all models comply with the formats in cobra. Models from USCD and Thiele labs should comply.
#
# **Base our code on metDataModel**
#
# Each model needs a list of Reactions, list of Pathways, and a list of Compounds.
# It's important to include with Compounds with all linked identifiers to other DBs (HMDB, PubChem, etc), and with formulae (usually charged form in these models) when available.
# We can alwasy update the data later. E.g. the neural formulae can be retrieved from HMDB if linked.
# Save in Python pickle and in JSON.
#
#
# Shuzhao Li, 2021-05-09, 05-10

# %%
# https://github.com/shuzhao-li/metDataModel/
# !pip install metDataModel
# Out:
# Collecting metDataModel
#   Downloading https://files.pythonhosted.org/packages/4a/e5/e4625fe421c74695a286bc1a289026ef1c1dff464e078c17fd9eed9167dd/metDataModel-0.3.0-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.2MB 926kB/s eta 0:00:01
# Installing collected packages: metDataModel
# Successfully installed metDataModel-0.3.0

# %%
from metDataModel.core import Compound, Reaction, Pathway, metabolicModel

# tool to parse XML - not needed if using cobra
import xml.etree.ElementTree as ET
# tool to parse Excel xlsx
import xlrd

# %%
! pip install cobra
# Out:
# Collecting cobra
#   Downloading https://files.pythonhosted.org/packages/c5/04/f785d34e11b42b21c101130d60324c90f58a612f49a6f95e1747f0f05ca1/cobra-0.22.0-py2.py3-none-any.whl (2.4MB)
#      |████████████████████████████████| 2.4MB 2.1MB/s eta 0:00:01
# Collecting optlang~=1.5 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/12/3e/9d0b72cf5a8ff660e5787a0797906e04942081f3ad4a95f860488affff2b/optlang-1.5.2-py2.py3-none-any.whl (147kB)
#      |████████████████████████████████| 153kB 2.5MB/s eta 0:00:01
# Collecting rich>=8.0 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/1a/da/2a1f064dc620ab47f3f826ae085384084b71ea05c8c21d67f1dfc29189ab/rich-10.1.0-py3-none-any.whl (201kB)
#      |████████████████████████████████| 204kB 3.0MB/s eta 0:00:01
# Collecting future (from cobra)
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 3.1MB/s eta 0:00:01
# Requirement already satisfied: numpy~=1.13 in /opt/conda/lib/python3.7/site-packages (from cobra) (1.17.2)
# Collecting httpx~=0.14 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/04/69/17b725b1bfe63228369cddf50206381eadb14bc46b933a864ae93ea1b9bf/httpx-0.18.1-py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 2.0MB/s eta 0:00:01
# Collecting pydantic~=1.6 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/8f/c4/a83f0b745d824a85ee5e4c8d26329d1c687b3a9303eca762dcc373721734/pydantic-1.8.1-py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 4.6MB/s eta 0:00:01
# Collecting appdirs~=1.4 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting swiglpk (from cobra)
#   Downloading https://files.pythonhosted.org/packages/80/48/ff3ce61567f667629268b272d4c57f980ff0a8d4bdf991a593be12384186/swiglpk-5.0.3-cp37-cp37m-manylinux2010_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 4.2MB/s eta 0:00:01
# Collecting pandas~=1.0 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/51/51/48f3fc47c4e2144da2806dfb6629c4dd1fa3d5a143f9652b141e979a8ca9/pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9MB)
#      |████████████████████████████████| 9.9MB 51.0MB/s eta 0:00:01
# Collecting diskcache~=5.0 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/6a/5e/3deb8f9c83bead2af6f2cda97c4400516488464fede2853875a81e502953/diskcache-5.2.1-py3-none-any.whl (44kB)
#      |████████████████████████████████| 51kB 1.6MB/s eta 0:00:01
# Collecting depinfo (from cobra)
#   Downloading https://files.pythonhosted.org/packages/af/8b/cee6dca4c4708705444c9cad9e783b9212cc51cab8a5e05ccfe930f53058/depinfo-1.7.0-py2.py3-none-any.whl
# Collecting importlib-resources (from cobra)
#   Downloading https://files.pythonhosted.org/packages/f0/5e/69e6a0602c1f18d390952177de648468c4a380252858b0022affc3ce7811/importlib_resources-5.1.2-py3-none-any.whl
# Collecting ruamel.yaml~=0.16 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/29/4e/c3105bbbbc662f6a671a505f00ec771e93b5254f09fbb06002af9087071a/ruamel.yaml-0.17.4-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 3.5MB/s ta 0:00:011
# Collecting python-libsbml==5.19.0 (from cobra)
#   Downloading https://files.pythonhosted.org/packages/93/13/2df22b77ee9125381a00aa4dc63de1776bb84d773655d2770416e81416cd/python_libsbml-5.19.0-cp37-cp37m-manylinux1_x86_64.whl (6.2MB)
#      |████████████████████████████████| 6.2MB 6.3MB/s eta 0:00:01
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.7/site-packages (from optlang~=1.5->cobra) (1.12.0)
# Requirement already satisfied: sympy>=1.0 in /opt/conda/lib/python3.7/site-packages (from optlang~=1.5->cobra) (1.4)
# Collecting colorama<0.5.0,>=0.4.0 (from rich>=8.0->cobra)
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting pygments<3.0.0,>=2.6.0 (from rich>=8.0->cobra)
#   Downloading https://files.pythonhosted.org/packages/a6/c9/be11fce9810793676017f79ffab3c6cb18575844a6c7b8d4ed92f95de604/Pygments-2.9.0-py3-none-any.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 13.9MB/s eta 0:00:01
# Collecting typing-extensions<4.0.0,>=3.7.4 (from rich>=8.0->cobra)
#   Downloading https://files.pythonhosted.org/packages/2e/35/6c4fff5ab443b57116cb1aad46421fb719bed2825664e8fe77d66d99bcbc/typing_extensions-3.10.0.0-py3-none-any.whl
# Collecting commonmark<0.10.0,>=0.9.0 (from rich>=8.0->cobra)
#   Downloading https://files.pythonhosted.org/packages/b1/92/dfd892312d822f36c55366118b95d914e5f16de11044a27cf10a7d71bbbf/commonmark-0.9.1-py2.py3-none-any.whl (51kB)
#      |████████████████████████████████| 51kB 2.6MB/s  eta 0:00:01
# Collecting httpcore<0.14.0,>=0.13.0 (from httpx~=0.14->cobra)
#   Downloading https://files.pythonhosted.org/packages/7a/89/29a26a8086268a8043b1fd0228a463bab99990d77fdfaa8a2bd07117851a/httpcore-0.13.3-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 3.3MB/s eta 0:00:011
# Collecting rfc3986[idna2008]<2,>=1.3 (from httpx~=0.14->cobra)
#   Downloading https://files.pythonhosted.org/packages/c4/e5/63ca2c4edf4e00657584608bee1001302bbf8c5f569340b78304f2f446cb/rfc3986-1.5.0-py2.py3-none-any.whl
# Collecting sniffio (from httpx~=0.14->cobra)
#   Downloading https://files.pythonhosted.org/packages/52/b0/7b2e028b63d092804b6794595871f936aafa5e9322dcaaad50ebf67445b3/sniffio-1.2.0-py3-none-any.whl
# Requirement already satisfied: certifi in /opt/conda/lib/python3.7/site-packages (from httpx~=0.14->cobra) (2019.6.16)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas~=1.0->cobra) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas~=1.0->cobra) (2019.2)
# Collecting importlib-metadata; python_version < "3.8" (from depinfo->cobra)
#   Downloading https://files.pythonhosted.org/packages/8e/e2/49966924c93909d47612bb47d911448140a2f6c1390aec2f4c1afbe3748f/importlib_metadata-4.0.1-py3-none-any.whl
# Collecting zipp>=0.4; python_version < "3.8" (from importlib-resources->cobra)
#   Downloading https://files.pythonhosted.org/packages/0f/8c/715c54e9e34c0c4820f616a913a7de3337d0cd79074dd1bed4dd840f16ae/zipp-3.4.1-py3-none-any.whl
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" (from ruamel.yaml~=0.16->cobra)
#   Downloading https://files.pythonhosted.org/packages/5e/6e/f652c56bbb2c3d3fca252ffc7c0358597f57a1bbdf484dac683054950c63/ruamel.yaml.clib-0.2.2-cp37-cp37m-manylinux1_x86_64.whl (547kB)
#      |████████████████████████████████| 552kB 11.9MB/s eta 0:00:01
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.7/site-packages (from sympy>=1.0->optlang~=1.5->cobra) (1.1.0)
# Collecting h11<0.13,>=0.11 (from httpcore<0.14.0,>=0.13.0->httpx~=0.14->cobra)
#   Downloading https://files.pythonhosted.org/packages/60/0f/7a0eeea938eaf61074f29fed9717f2010e8d0e0905d36b38d3275a1e4622/h11-0.12.0-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 2.2MB/s eta 0:00:011
# Requirement already satisfied: idna; extra == "idna2008" in /opt/conda/lib/python3.7/site-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra) (2.8)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp37-none-any.whl size=491057 sha256=5fa480e3d4a477449052cf4dd6c809a9167a799cc87bec30c93102be439d0e85
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# Installing collected packages: swiglpk, optlang, colorama, pygments, typing-extensions, commonmark, rich, future, sniffio, h11, httpcore, rfc3986, httpx, pydantic, appdirs, pandas, diskcache, zipp, importlib-metadata, depinfo, importlib-resources, ruamel.yaml.clib, ruamel.yaml, python-libsbml, cobra
#   Found existing installation: Pygments 2.4.2
#     Uninstalling Pygments-2.4.2:
#       Successfully uninstalled Pygments-2.4.2
#   Found existing installation: pandas 0.25.1
#     Uninstalling pandas-0.25.1:
#       Successfully uninstalled pandas-0.25.1
# Successfully installed appdirs-1.4.4 cobra-0.22.0 colorama-0.4.4 commonmark-0.9.1 depinfo-1.7.0 diskcache-5.2.1 future-0.18.2 h11-0.12.0 httpcore-0.13.3 httpx-0.18.1 importlib-metadata-4.0.1 importlib-resources-5.1.2 optlang-1.5.2 pandas-1.2.4 pydantic-1.8.1 pygments-2.9.0 python-libsbml-5.19.0 rfc3986-1.5.0 rich-10.1.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 sniffio-1.2.0 swiglpk-5.0.3 typing-extensions-3.10.0.0 zipp-3.4.1

# %%
import cobra

# https://cobrapy.readthedocs.io/en/latest/io.html#SBML

# %%
# cloned from
# https://github.com/VirtualMetabolicHuman
# 2021-05-08
# this is the more inclusive model. The other Recon3DModel_301 is flux constrainted.
R3D = "thiele/Recon/Current_Version/Recon3D_301_Reconstruction/Recon3D_301.xml"

model = cobra.io.read_sbml_model(R3D)

model
# Out:
# <Model COBRAModel at 0x7fbf4543dc88>

# %%
dir(model)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotation',
#  '_compartments',
#  '_contexts',
#  '_id',
#  '_populate_solver',
#  '_repr_html_',
#  '_sbml',
#  '_set_id_with_model',
#  '_solver',
#  '_tolerance',
#  '_trimmed',
#  '_trimmed_genes',
#  '_trimmed_reactions',
#  'add_boundary',
#  'add_cons_vars',
#  'add_groups',
#  'add_metabolites',
#  'add_reaction',
#  'add_reactions',
#  'annotation',
#  'boundary',
#  'compartments',
#  'constraints',
#  'copy',
#  'demands',
#  'description',
#  'exchanges',
#  'genes',
#  'get_associated_groups',
#  'get_metabolite_compartments',
#  'groups',
#  'id',
#  'medium',
#  'merge',
#  'metabolites',
#  'name',
#  'notes',
#  'objective',
#  'objective_direction',
#  'optimize',
#  'problem',
#  'reactions',
#  'remove_cons_vars',
#  'remove_groups',
#  'remove_metabolites',
#  'remove_reactions',
#  'repair',
#  'sinks',
#  'slim_optimize',
#  'solver',
#  'summary',
#  'tolerance',
#  'variables']

# %%
model.metabolites[33].annotation
# Out:
# {'hmdb': 'HMDB06225',
#  'inchi': 'InChI=1S/C28H44O3/c1-18(9-10-19(2)27(4,5)31)24-13-14-25-21(8-7-15-28(24,25)6)11-12-22-16-23(29)17-26(30)20(22)3/h9-12,18-19,23-26,29-31H,3,7-8,13-17H2,1-2,4-6H3/b10-9+,21-11+,22-12-/t18-,19+,23-,24-,25+,26+,28-/m1/s1',
#  'pubchem.compound': '9547243'}

# %%
dir(model.metabolites[33])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotation',
#  '_bound',
#  '_id',
#  '_model',
#  '_reaction',
#  '_repr_html_',
#  '_set_id_with_model',
#  'annotation',
#  'charge',
#  'compartment',
#  'constraint',
#  'copy',
#  'elements',
#  'formula',
#  'formula_weight',
#  'id',
#  'model',
#  'name',
#  'notes',
#  'reactions',
#  'remove_from_model',
#  'shadow_price',
#  'summary',
#  'y']

# %%
[model.metabolites[33].formula,
model.metabolites[33].charge,
 model.metabolites[33].name,
 model.metabolites[33].id,
 model.metabolites[33]._id,
 model.metabolites[33].annotation
]
# Out:
# ['C28H44O3',
#  0,
#  '1-Alpha,25-Dihydroxyvitamin D2',
#  '1a25dhvitd2[m]',
#  '1a25dhvitd2[m]',
#  {'hmdb': 'HMDB06225',
#   'inchi': 'InChI=1S/C28H44O3/c1-18(9-10-19(2)27(4,5)31)24-13-14-25-21(8-7-15-28(24,25)6)11-12-22-16-23(29)17-26(30)20(22)3/h9-12,18-19,23-26,29-31H,3,7-8,13-17H2,1-2,4-6H3/b10-9+,21-11+,22-12-/t18-,19+,23-,24-,25+,26+,28-/m1/s1',
#   'pubchem.compound': '9547243'}]

# %%
len( model.reactions )
# Out:
# 13543

# %%
model.reactions[33]
# Out:
# <Reaction 25VITD2Hm at 0x7fbf62abc4e0>

# %%
dir(model.reactions[33])
# Out:
# ['__add__',
#  '__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotation',
#  '_associate_gene',
#  '_check_bounds',
#  '_dissociate_gene',
#  '_gene_reaction_rule',
#  '_genes',
#  '_id',
#  '_lower_bound',
#  '_metabolites',
#  '_model',
#  '_repr_html_',
#  '_set_id_with_model',
#  '_update_awareness',
#  '_upper_bound',
#  'add_metabolites',
#  'annotation',
#  'boundary',
#  'bounds',
#  'build_reaction_from_string',
#  'build_reaction_string',
#  'check_mass_balance',
#  'compartments',
#  'copy',
#  'delete',
#  'flux',
#  'flux_expression',
#  'forward_variable',
#  'functional',
#  'gene_name_reaction_rule',
#  'gene_reaction_rule',
#  'genes',
#  'get_coefficient',
#  'get_coefficients',
#  'get_compartments',
#  'id',
#  'knock_out',
#  'lower_bound',
#  'metabolites',
#  'model',
#  'name',
#  'notes',
#  'objective_coefficient',
#  'products',
#  'reactants',
#  'reaction',
#  'reduced_cost',
#  'remove_from_model',
#  'reverse_id',
#  'reverse_variable',
#  'reversibility',
#  'subsystem',
#  'subtract_metabolites',
#  'summary',
#  'update_variable_bounds',
#  'upper_bound',
#  'x',
#  'y']

# %%
model.reactions[33].reactants
# Out:
# [<Metabolite h2o[m] at 0x7fbf454644e0>,
#  <Metabolite nadp[m] at 0x7fbf45464940>,
#  <Metabolite 1a25dhvitd2[m] at 0x7fbf45464c50>]

# %%
model.reactions[33].reactants
# Out:
# [<Metabolite o2[m] at 0x7fbf454646a0>,
#  <Metabolite h[m] at 0x7fbf45464860>,
#  <Metabolite nadph[m] at 0x7fbf45464748>,
#  <Metabolite 25hvitd2[m] at 0x7fbf45467f98>]

# %%
model.reactions[33].reactants[3].annotation
# Out:
# {'hmdb': 'HMDB01438', 'pubchem.compound': '22833566'}

# %%
model.reactions[33].reactants[3].id
# Out:
# '25hvitd2[m]'

# %%
model.reactions[33].subsystem
# Out:
# ''

# %%
model.groups[33]
# Out:
# <Group group34 at 0x7fbf42da0e10>

# %%
dir(model.groups[33])
# Out:
# ['KIND_TYPES',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotation',
#  '_id',
#  '_kind',
#  '_members',
#  '_model',
#  '_set_id_with_model',
#  'add_members',
#  'annotation',
#  'id',
#  'kind',
#  'members',
#  'name',
#  'notes',
#  'remove_members']

# %%
[
    model.groups[33].name,
    model.groups[33].members,
    model.groups[33].annotation,
]
# Out:
# ['Glycine, serine, alanine, and threonine metabolism',
#  [<Reaction 2AMACHYD at 0x7fbf62abccf8>,
#   <Reaction AACTOOR at 0x7fbf62985fd0>,
#   <Reaction ALASm at 0x7fbf62862c18>,
#   <Reaction AOBUTDsm at 0x7fbf627cae48>,
#   <Reaction BETALDHxm at 0x7fbf626c74a8>,
#   <Reaction BHMT at 0x7fbf6273c710>,
#   <Reaction CHOLD2m at 0x7fbf4537e6a0>,
#   <Reaction DMGDHm at 0x7fbf45227b70>,
#   <Reaction GCC2am at 0x7fbf44d17208>,
#   <Reaction GCC2bim at 0x7fbf44d17780>,
#   <Reaction GCC2cm at 0x7fbf44d17b70>,
#   <Reaction GCCam at 0x7fbf44cf7828>,
#   <Reaction GCCbim at 0x7fbf44d223c8>,
#   <Reaction GCCcm at 0x7fbf44d0def0>,
#   <Reaction GHMT2rm at 0x7fbf44cda0f0>,
#   <Reaction GLYATm at 0x7fbf44bf9d68>,
#   <Reaction GLYOp at 0x7fbf44c07940>,
#   <Reaction GNMT at 0x7fbf44c1c5f8>,
#   <Reaction PGCD at 0x7fbf4468c828>,
#   <Reaction SARCOXp at 0x7fbf4441ae10>,
#   <Reaction SERHL at 0x7fbf443d0eb8>,
#   <Reaction SPTix at 0x7fbf44332eb8>,
#   <Reaction r0160 at 0x7fbf44167eb8>,
#   <Reaction r0552 at 0x7fbf43ff1ef0>,
#   <Reaction r0553 at 0x7fbf43ff1e10>,
#   <Reaction RE2111M at 0x7fbf43296b00>,
#   <Reaction RE2117M at 0x7fbf432a2390>,
#   <Reaction RE2427M at 0x7fbf431d66a0>,
#   <Reaction RE2428M at 0x7fbf431d6b38>,
#   <Reaction RE2429M at 0x7fbf431d6da0>,
#   <Reaction GLYACm at 0x7fbf423c6a20>,
#   <Reaction THRACm at 0x7fbf423999b0>,
#   <Reaction ACHOMm at 0x7fbf42347828>,
#   <Reaction GHMT2r at 0x7fbf41dd6e80>,
#   <Reaction PSERT at 0x7fbf41d50a58>,
#   <Reaction PSP_L at 0x7fbf41d5ac18>,
#   <Reaction THRS at 0x7fbf41d08748>,
#   <Reaction THRD_L at 0x7fbf41c08208>,
#   <Reaction OBDHc at 0x7fbf41bb8a20>,
#   <Reaction PPIOGLYc at 0x7fbf41b804a8>,
#   <Reaction TIGGLYc at 0x7fbf41b932e8>,
#   <Reaction HEXGLYc at 0x7fbf41b3f828>,
#   <Reaction SUBGLYc at 0x7fbf41b54198>,
#   <Reaction HMR_4284 at 0x7fbf40754e10>,
#   <Reaction HMR_4466 at 0x7fbf407620f0>,
#   <Reaction HMR_4696 at 0x7fbf40762160>,
#   <Reaction HMR_4700 at 0x7fbf406f89b0>,
#   <Reaction HMR_7703 at 0x7fbf40200748>,
#   <Reaction HMR_9718 at 0x7fbf3ff6fac8>],
#  {'sbo': 'SBO:0000633'}]

# %% [markdown]
# ## Summary
#
# - metabolites and reactions are quite standard.
# - subsystem may not be defined in these SBML files.
# - use "group" as pathway
#
# Targeted structure in Azimuth
#
# ```
# │   ├── RECON3D (document)
# │   │   ├── Reactions (subcollection)
# │   │   ├── Compounds (subcollection)
# │   │   └── Pathways (subcollection)
# ```
#
# We will export one .py and one JSON per model.

# %%
# from metDataModel.core import Compound, Reaction, Pathway, metabolicModel

def metabolite2compound(M):
    # convert cobra Metabolite to metDataModel Compound
    Cpd = Compound()
    Cpd.src_id = M.id
    Cpd.id = M.id.split("[")[0]
    Cpd.name = M.name
    Cpd.charge = M.charge
    Cpd.charged_formula = M.formula
    Cpd.db_ids = M.annotation
    return Cpd

metabolite2compound(model.metabolites[33]).id
# Out:
# '1a25dhvitd2'

# %%
# list of Compounds
myCpds = []
anno = {}
for M in model.metabolites:
    anno[M.id.split("[")[0]] = M.annotation
    myCpds.append(metabolite2compound(M))
    
print("total, ", len(myCpds), len(anno))

unique = set([C.id for C in myCpds])
formula = set([C.charged_formula for C in myCpds if C.charged_formula])
# a little tricker to test on dictionaries
annotation = [v for v in anno.values() if v]

print("real, ", len(unique), len(formula), len(annotation))
# Out:
# total,  8399 4140
# real,  4140 2631 2943

# %% [markdown]
# ### Numbers in RECON3D
#
# len(unique), len(formula), len(annotation) =
# 4140, 2631, 2943

# %% [markdown]
# ## Now do ATLAS

# %%
xmlFile = 'Human-GEM/ModelFiles/xml/HumanGEM.xml'
excelFile = 'Human-GEM/ModelFiles/xlsx/HumanGEM.xlsx'

model2 = cobra.io.read_sbml_model(xmlFile)

model2
# Out:
# '' is not a valid SBML 'SId'.
# Adding exchange reaction EX_m00001x with default bounds for boundary metabolite: m00001x.
# Adding exchange reaction EX_m00002x with default bounds for boundary metabolite: m00002x.
# Adding exchange reaction EX_m00032x with default bounds for boundary metabolite: m00032x.
# Adding exchange reaction EX_m00035x with default bounds for boundary metabolite: m00035x.
# Adding exchange reaction EX_m00097x with default bounds for boundary metabolite: m00097x.
# Adding exchange reaction EX_m00157x with default bounds for boundary metabolite: m00157x.
# Adding exchange reaction EX_m00179x with default bounds for boundary metabolite: m00179x.
# Adding exchange reaction EX_m00204x with default bounds for boundary metabolite: m00204x.
# Adding exchange reaction EX_m00228x with default bounds for boundary metabolite: m00228x.
# Adding exchange reaction EX_m00242x with default bounds for boundary metabolite: m00242x.
# Adding exchange reaction EX_m00266x with default bounds for boundary metabolite: m00266x.
# Adding exchange reaction EX_m00267x with default bounds for boundary metabolite: m00267x.
# Adding exchange reaction EX_m00268x with default bounds for boundary metabolite: m00268x.
# Adding exchange reaction EX_m00269x with default bounds for boundary metabolite: m00269x.
# Adding exchange reaction EX_m00325x with default bounds for boundary metabolite: m00325x.
# Adding exchange reaction EX_m00353x with default bounds for boundary metabolite: m00353x.
# Adding exchange reaction EX_m00371x with default bounds for boundary metabolite: m00371x.
# Adding exchange reaction EX_m00402x with default bounds for boundary metabolite: m00402x.
# Adding exchange reaction EX_m00403x with default bounds for boundary metabolite: m00403x.
# Adding exchange reaction EX_m00432x with default bounds for boundary metabolite: m00432x.
# Adding exchange reaction EX_m00516x with default bounds for boundary metabolite: m00516x.
# Adding exchange reaction EX_m00536x with default bounds for boundary metabolite: m00536x.
# Adding exchange reaction EX_m00545x with default bounds for boundary metabolite: m00545x.
# Adding exchange reaction EX_m00549x with default bounds for boundary metabolite: m00549x.
# Adding exchange reaction EX_m00577x with default bounds for boundary metabolite: m00577x.
# Adding exchange reaction EX_m00580x with default bounds for boundary metabolite: m00580x.
# Adding exchange reaction EX_m00613x with default bounds for boundary metabolite: m00613x.
# Adding exchange reaction EX_m00620x with default bounds for boundary metabolite: m00620x.
# Adding exchange reaction EX_m00626x with default bounds for boundary metabolite: m00626x.
# Adding exchange reaction EX_m00648x with default bounds for boundary metabolite: m00648x.
# Adding exchange reaction EX_m00665x with default bounds for boundary metabolite: m00665x.
# Adding exchange reaction EX_m00730x with default bounds for boundary metabolite: m00730x.
# Adding exchange reaction EX_m00734x with default bounds for boundary metabolite: m00734x.
# Adding exchange reaction EX_m00744x with default bounds for boundary metabolite: m00744x.
# Adding exchange reaction EX_m00771x with default bounds for boundary metabolite: m00771x.
# Adding exchange reaction EX_m00816x with default bounds for boundary metabolite: m00816x.
# Adding exchange reaction EX_m00932x with default bounds for boundary metabolite: m00932x.
# Adding exchange reaction EX_m00970x with default bounds for boundary metabolite: m00970x.
# Adding exchange reaction EX_m00986x with default bounds for boundary metabolite: m00986x.
# Adding exchange reaction EX_m00998x with default bounds for boundary metabolite: m00998x.
# Adding exchange reaction EX_m01003x with default bounds for boundary metabolite: m01003x.
# Adding exchange reaction EX_m01006x with default bounds for boundary metabolite: m01006x.
# Adding exchange reaction EX_m01007x with default bounds for boundary metabolite: m01007x.
# Adding exchange reaction EX_m01019x with default bounds for boundary metabolite: m01019x.
# Adding exchange reaction EX_m01020x with default bounds for boundary metabolite: m01020x.
# Adding exchange reaction EX_m01021x with default bounds for boundary metabolite: m01021x.
# Adding exchange reaction EX_m01033x with default bounds for boundary metabolite: m01033x.
# Adding exchange reaction EX_m01069x with default bounds for boundary metabolite: m01069x.
# Adding exchange reaction EX_m01070x with default bounds for boundary metabolite: m01070x.
# Adding exchange reaction EX_m01071x with default bounds for boundary metabolite: m01071x.
# Adding exchange reaction EX_m01098x with default bounds for boundary metabolite: m01098x.
# Adding exchange reaction EX_m01100x with default bounds for boundary metabolite: m01100x.
# Adding exchange reaction EX_m01107x with default bounds for boundary metabolite: m01107x.
# Adding exchange reaction EX_m01109x with default bounds for boundary metabolite: m01109x.
# Adding exchange reaction EX_m01111x with default bounds for boundary metabolite: m01111x.
# Adding exchange reaction EX_m01115x with default bounds for boundary metabolite: m01115x.
# Adding exchange reaction EX_m01158x with default bounds for boundary metabolite: m01158x.
# Adding exchange reaction EX_m01159x with default bounds for boundary metabolite: m01159x.
# Adding exchange reaction EX_m01163x with default bounds for boundary metabolite: m01163x.
# Adding exchange reaction EX_m01174x with default bounds for boundary metabolite: m01174x.
# Adding exchange reaction EX_m01244x with default bounds for boundary metabolite: m01244x.
# Adding exchange reaction EX_m01245x with default bounds for boundary metabolite: m01245x.
# Adding exchange reaction EX_m01249x with default bounds for boundary metabolite: m01249x.
# Adding exchange reaction EX_m01252x with default bounds for boundary metabolite: m01252x.
# Adding exchange reaction EX_m01253x with default bounds for boundary metabolite: m01253x.
# Adding exchange reaction EX_m01256x with default bounds for boundary metabolite: m01256x.
# Adding exchange reaction EX_m01260x with default bounds for boundary metabolite: m01260x.
# Adding exchange reaction EX_m01279x with default bounds for boundary metabolite: m01279x.
# Adding exchange reaction EX_m01280x with default bounds for boundary metabolite: m01280x.
# Adding exchange reaction EX_m01285x with default bounds for boundary metabolite: m01285x.
# Adding exchange reaction EX_m01286x with default bounds for boundary metabolite: m01286x.
# Adding exchange reaction EX_m01287x with default bounds for boundary metabolite: m01287x.
# Adding exchange reaction EX_m01288x with default bounds for boundary metabolite: m01288x.
# Adding exchange reaction EX_m01289x with default bounds for boundary metabolite: m01289x.
# Adding exchange reaction EX_m01290x with default bounds for boundary metabolite: m01290x.
# Adding exchange reaction EX_m01296x with default bounds for boundary metabolite: m01296x.
# Adding exchange reaction EX_m01298x with default bounds for boundary metabolite: m01298x.
# Adding exchange reaction EX_m01303x with default bounds for boundary metabolite: m01303x.
# Adding exchange reaction EX_m01306x with default bounds for boundary metabolite: m01306x.
# Adding exchange reaction EX_m01307x with default bounds for boundary metabolite: m01307x.
# Adding exchange reaction EX_m01308x with default bounds for boundary metabolite: m01308x.
# Adding exchange reaction EX_m01309x with default bounds for boundary metabolite: m01309x.
# Adding exchange reaction EX_m01326x with default bounds for boundary metabolite: m01326x.
# Adding exchange reaction EX_m01327x with default bounds for boundary metabolite: m01327x.
# Adding exchange reaction EX_m01330x with default bounds for boundary metabolite: m01330x.
# Adding exchange reaction EX_m01334x with default bounds for boundary metabolite: m01334x.
# Adding exchange reaction EX_m01338x with default bounds for boundary metabolite: m01338x.
# Adding exchange reaction EX_m01339x with default bounds for boundary metabolite: m01339x.
# Adding exchange reaction EX_m01344x with default bounds for boundary metabolite: m01344x.
# Adding exchange reaction EX_m01356x with default bounds for boundary metabolite: m01356x.
# Adding exchange reaction EX_m01361x with default bounds for boundary metabolite: m01361x.
# Adding exchange reaction EX_m01365x with default bounds for boundary metabolite: m01365x.
# Adding exchange reaction EX_m01368x with default bounds for boundary metabolite: m01368x.
# Adding exchange reaction EX_m01369x with default bounds for boundary metabolite: m01369x.
# Adding exchange reaction EX_m01370x with default bounds for boundary metabolite: m01370x.
# Adding exchange reaction EX_m01374x with default bounds for boundary metabolite: m01374x.
# Adding exchange reaction EX_m01383x with default bounds for boundary metabolite: m01383x.
# Adding exchange reaction EX_m01385x with default bounds for boundary metabolite: m01385x.
# Adding exchange reaction EX_m01393x with default bounds for boundary metabolite: m01393x.
# Adding exchange reaction EX_m01396x with default bounds for boundary metabolite: m01396x.
# Adding exchange reaction EX_m01397x with default bounds for boundary metabolite: m01397x.
# Adding exchange reaction EX_m01398x with default bounds for boundary metabolite: m01398x.
# Adding exchange reaction EX_m01400x with default bounds for boundary metabolite: m01400x.
# Adding exchange reaction EX_m01401x with default bounds for boundary metabolite: m01401x.
# Adding exchange reaction EX_m01403x with default bounds for boundary metabolite: m01403x.
# Adding exchange reaction EX_m01410x with default bounds for boundary metabolite: m01410x.
# Adding exchange reaction EX_m01413x with default bounds for boundary metabolite: m01413x.
# Adding exchange reaction EX_m01415x with default bounds for boundary metabolite: m01415x.
# Adding exchange reaction EX_m01418x with default bounds for boundary metabolite: m01418x.
# Adding exchange reaction EX_m01419x with default bounds for boundary metabolite: m01419x.
# Adding exchange reaction EX_m01433x with default bounds for boundary metabolite: m01433x.
# Adding exchange reaction EX_m01438x with default bounds for boundary metabolite: m01438x.
# Adding exchange reaction EX_m01442x with default bounds for boundary metabolite: m01442x.
# Adding exchange reaction EX_m01445x with default bounds for boundary metabolite: m01445x.
# Adding exchange reaction EX_m01450x with default bounds for boundary metabolite: m01450x.
# Adding exchange reaction EX_m01513x with default bounds for boundary metabolite: m01513x.
# Adding exchange reaction EX_m01517x with default bounds for boundary metabolite: m01517x.
# Adding exchange reaction EX_m01525x with default bounds for boundary metabolite: m01525x.
# Adding exchange reaction EX_m01533x with default bounds for boundary metabolite: m01533x.
# Adding exchange reaction EX_m01543x with default bounds for boundary metabolite: m01543x.
# Adding exchange reaction EX_m01554x with default bounds for boundary metabolite: m01554x.
# Adding exchange reaction EX_m01569x with default bounds for boundary metabolite: m01569x.
# Adding exchange reaction EX_m01570x with default bounds for boundary metabolite: m01570x.
# Adding exchange reaction EX_m01587x with default bounds for boundary metabolite: m01587x.
# Adding exchange reaction EX_m01588x with default bounds for boundary metabolite: m01588x.
# Adding exchange reaction EX_m01590x with default bounds for boundary metabolite: m01590x.
# Adding exchange reaction EX_m01595x with default bounds for boundary metabolite: m01595x.
# Adding exchange reaction EX_m01596x with default bounds for boundary metabolite: m01596x.
# Adding exchange reaction EX_m01603x with default bounds for boundary metabolite: m01603x.
# Adding exchange reaction EX_m01604x with default bounds for boundary metabolite: m01604x.
# Adding exchange reaction EX_m01610x with default bounds for boundary metabolite: m01610x.
# Adding exchange reaction EX_m01612x with default bounds for boundary metabolite: m01612x.
# Adding exchange reaction EX_m01613x with default bounds for boundary metabolite: m01613x.
# Adding exchange reaction EX_m01614x with default bounds for boundary metabolite: m01614x.
# Adding exchange reaction EX_m01615x with default bounds for boundary metabolite: m01615x.
# Adding exchange reaction EX_m01617x with default bounds for boundary metabolite: m01617x.
# Adding exchange reaction EX_m01619x with default bounds for boundary metabolite: m01619x.
# Adding exchange reaction EX_m01621x with default bounds for boundary metabolite: m01621x.
# Adding exchange reaction EX_m01626x with default bounds for boundary metabolite: m01626x.
# Adding exchange reaction EX_m01628x with default bounds for boundary metabolite: m01628x.
# Adding exchange reaction EX_m01629x with default bounds for boundary metabolite: m01629x.
# Adding exchange reaction EX_m01630x with default bounds for boundary metabolite: m01630x.
# Adding exchange reaction EX_m01632x with default bounds for boundary metabolite: m01632x.
# Adding exchange reaction EX_m01633x with default bounds for boundary metabolite: m01633x.
# Adding exchange reaction EX_m01638x with default bounds for boundary metabolite: m01638x.
# Adding exchange reaction EX_m01640x with default bounds for boundary metabolite: m01640x.
# Adding exchange reaction EX_m01641x with default bounds for boundary metabolite: m01641x.
# Adding exchange reaction EX_m01647x with default bounds for boundary metabolite: m01647x.
# Adding exchange reaction EX_m01648x with default bounds for boundary metabolite: m01648x.
# Adding exchange reaction EX_m01652x with default bounds for boundary metabolite: m01652x.
# Adding exchange reaction EX_m01655x with default bounds for boundary metabolite: m01655x.
# Adding exchange reaction EX_m01659x with default bounds for boundary metabolite: m01659x.
# Adding exchange reaction EX_m01665x with default bounds for boundary metabolite: m01665x.
# Adding exchange reaction EX_m01666x with default bounds for boundary metabolite: m01666x.
# Adding exchange reaction EX_m01668x with default bounds for boundary metabolite: m01668x.
# Adding exchange reaction EX_m01669x with default bounds for boundary metabolite: m01669x.
# Adding exchange reaction EX_m01671x with default bounds for boundary metabolite: m01671x.
# Adding exchange reaction EX_m01672x with default bounds for boundary metabolite: m01672x.
# Adding exchange reaction EX_m01673x with default bounds for boundary metabolite: m01673x.
# Adding exchange reaction EX_m01682x with default bounds for boundary metabolite: m01682x.
# Adding exchange reaction EX_m01687x with default bounds for boundary metabolite: m01687x.
# Adding exchange reaction EX_m01695x with default bounds for boundary metabolite: m01695x.
# Adding exchange reaction EX_m01700x with default bounds for boundary metabolite: m01700x.
# Adding exchange reaction EX_m01704x with default bounds for boundary metabolite: m01704x.
# Adding exchange reaction EX_m01711x with default bounds for boundary metabolite: m01711x.
# Adding exchange reaction EX_m01712x with default bounds for boundary metabolite: m01712x.
# Adding exchange reaction EX_m01714x with default bounds for boundary metabolite: m01714x.
# Adding exchange reaction EX_m01716x with default bounds for boundary metabolite: m01716x.
# Adding exchange reaction EX_m01730x with default bounds for boundary metabolite: m01730x.
# Adding exchange reaction EX_m01736x with default bounds for boundary metabolite: m01736x.
# Adding exchange reaction EX_m01737x with default bounds for boundary metabolite: m01737x.
# Adding exchange reaction EX_m01740x with default bounds for boundary metabolite: m01740x.
# Adding exchange reaction EX_m01742x with default bounds for boundary metabolite: m01742x.
# Adding exchange reaction EX_m01743x with default bounds for boundary metabolite: m01743x.
# Adding exchange reaction EX_m01744x with default bounds for boundary metabolite: m01744x.
# Adding exchange reaction EX_m01745x with default bounds for boundary metabolite: m01745x.
# Adding exchange reaction EX_m01758x with default bounds for boundary metabolite: m01758x.
# Adding exchange reaction EX_m01765x with default bounds for boundary metabolite: m01765x.
# Adding exchange reaction EX_m01768x with default bounds for boundary metabolite: m01768x.
# Adding exchange reaction EX_m01786x with default bounds for boundary metabolite: m01786x.
# Adding exchange reaction EX_m01787x with default bounds for boundary metabolite: m01787x.
# Adding exchange reaction EX_m01788x with default bounds for boundary metabolite: m01788x.
# Adding exchange reaction EX_m01789x with default bounds for boundary metabolite: m01789x.
# Adding exchange reaction EX_m01795x with default bounds for boundary metabolite: m01795x.
# Adding exchange reaction EX_m01796x with default bounds for boundary metabolite: m01796x.
# Adding exchange reaction EX_m01797x with default bounds for boundary metabolite: m01797x.
# Adding exchange reaction EX_m01799x with default bounds for boundary metabolite: m01799x.
# Adding exchange reaction EX_m01800x with default bounds for boundary metabolite: m01800x.
# Adding exchange reaction EX_m02458x with default bounds for boundary metabolite: m02458x.
# Adding exchange reaction EX_m01821x with default bounds for boundary metabolite: m01821x.
# Adding exchange reaction EX_m01822x with default bounds for boundary metabolite: m01822x.
# Adding exchange reaction EX_m01830x with default bounds for boundary metabolite: m01830x.
# Adding exchange reaction EX_m01833x with default bounds for boundary metabolite: m01833x.
# Adding exchange reaction EX_m01840x with default bounds for boundary metabolite: m01840x.
# Adding exchange reaction EX_m01850x with default bounds for boundary metabolite: m01850x.
# Adding exchange reaction EX_m01851x with default bounds for boundary metabolite: m01851x.
# Adding exchange reaction EX_m01852x with default bounds for boundary metabolite: m01852x.
# Adding exchange reaction EX_m01853x with default bounds for boundary metabolite: m01853x.
# Adding exchange reaction EX_m01859x with default bounds for boundary metabolite: m01859x.
# Adding exchange reaction EX_m01861x with default bounds for boundary metabolite: m01861x.
# Adding exchange reaction EX_m01870x with default bounds for boundary metabolite: m01870x.
# Adding exchange reaction EX_m01872x with default bounds for boundary metabolite: m01872x.
# Adding exchange reaction EX_m01874x with default bounds for boundary metabolite: m01874x.
# Adding exchange reaction EX_m01881x with default bounds for boundary metabolite: m01881x.
# Adding exchange reaction EX_m01883x with default bounds for boundary metabolite: m01883x.
# Adding exchange reaction EX_m01884x with default bounds for boundary metabolite: m01884x.
# Adding exchange reaction EX_m01887x with default bounds for boundary metabolite: m01887x.
# Adding exchange reaction EX_m01910x with default bounds for boundary metabolite: m01910x.
# Adding exchange reaction EX_m01913x with default bounds for boundary metabolite: m01913x.
# Adding exchange reaction EX_m01914x with default bounds for boundary metabolite: m01914x.
# Adding exchange reaction EX_m01915x with default bounds for boundary metabolite: m01915x.
# Adding exchange reaction EX_m01916x with default bounds for boundary metabolite: m01916x.
# Adding exchange reaction EX_m01917x with default bounds for boundary metabolite: m01917x.
# Adding exchange reaction EX_m01919x with default bounds for boundary metabolite: m01919x.
# Adding exchange reaction EX_m01935x with default bounds for boundary metabolite: m01935x.
# Adding exchange reaction EX_m01938x with default bounds for boundary metabolite: m01938x.
# Adding exchange reaction EX_m01944x with default bounds for boundary metabolite: m01944x.
# Adding exchange reaction EX_m01945x with default bounds for boundary metabolite: m01945x.
# Adding exchange reaction EX_m01948x with default bounds for boundary metabolite: m01948x.
# Adding exchange reaction EX_m01955x with default bounds for boundary metabolite: m01955x.
# Adding exchange reaction EX_m01959x with default bounds for boundary metabolite: m01959x.
# Adding exchange reaction EX_m01962x with default bounds for boundary metabolite: m01962x.
# Adding exchange reaction EX_m01965x with default bounds for boundary metabolite: m01965x.
# Adding exchange reaction EX_m01966x with default bounds for boundary metabolite: m01966x.
# Adding exchange reaction EX_m01974x with default bounds for boundary metabolite: m01974x.
# Adding exchange reaction EX_m01975x with default bounds for boundary metabolite: m01975x.
# Adding exchange reaction EX_m01982x with default bounds for boundary metabolite: m01982x.
# Adding exchange reaction EX_m01983x with default bounds for boundary metabolite: m01983x.
# Adding exchange reaction EX_m01986x with default bounds for boundary metabolite: m01986x.
# Adding exchange reaction EX_m01987x with default bounds for boundary metabolite: m01987x.
# Adding exchange reaction EX_m01988x with default bounds for boundary metabolite: m01988x.
# Adding exchange reaction EX_m01989x with default bounds for boundary metabolite: m01989x.
# Adding exchange reaction EX_m03161x with default bounds for boundary metabolite: m03161x.
# Adding exchange reaction EX_m01999x with default bounds for boundary metabolite: m01999x.
# Adding exchange reaction EX_m02001x with default bounds for boundary metabolite: m02001x.
# Adding exchange reaction EX_m02016x with default bounds for boundary metabolite: m02016x.
# Adding exchange reaction EX_m02018x with default bounds for boundary metabolite: m02018x.
# Adding exchange reaction EX_m02019x with default bounds for boundary metabolite: m02019x.
# Adding exchange reaction EX_m02022x with default bounds for boundary metabolite: m02022x.
# Adding exchange reaction EX_m02023x with default bounds for boundary metabolite: m02023x.
# Adding exchange reaction EX_m02024x with default bounds for boundary metabolite: m02024x.
# Adding exchange reaction EX_m02026x with default bounds for boundary metabolite: m02026x.
# Adding exchange reaction EX_m02027x with default bounds for boundary metabolite: m02027x.
# Adding exchange reaction EX_m02028x with default bounds for boundary metabolite: m02028x.
# Adding exchange reaction EX_m02034x with default bounds for boundary metabolite: m02034x.
# Adding exchange reaction EX_m02037x with default bounds for boundary metabolite: m02037x.
# Adding exchange reaction EX_m02038x with default bounds for boundary metabolite: m02038x.
# Adding exchange reaction EX_m02039x with default bounds for boundary metabolite: m02039x.
# Adding exchange reaction EX_m02040x with default bounds for boundary metabolite: m02040x.
# Adding exchange reaction EX_m02041x with default bounds for boundary metabolite: m02041x.
# Adding exchange reaction EX_m02042x with default bounds for boundary metabolite: m02042x.
# Adding exchange reaction EX_m02046x with default bounds for boundary metabolite: m02046x.
# Adding exchange reaction EX_m02047x with default bounds for boundary metabolite: m02047x.
# Adding exchange reaction EX_m02048x with default bounds for boundary metabolite: m02048x.
# Adding exchange reaction EX_m02049x with default bounds for boundary metabolite: m02049x.
# Adding exchange reaction EX_m02050x with default bounds for boundary metabolite: m02050x.
# Adding exchange reaction EX_m02054x with default bounds for boundary metabolite: m02054x.
# Adding exchange reaction EX_m02104x with default bounds for boundary metabolite: m02104x.
# Adding exchange reaction EX_m02105x with default bounds for boundary metabolite: m02105x.
# Adding exchange reaction EX_m02108x with default bounds for boundary metabolite: m02108x.
# Adding exchange reaction EX_m02118x with default bounds for boundary metabolite: m02118x.
# Adding exchange reaction EX_m02119x with default bounds for boundary metabolite: m02119x.
# Adding exchange reaction EX_m02120x with default bounds for boundary metabolite: m02120x.
# Adding exchange reaction EX_m02125x with default bounds for boundary metabolite: m02125x.
# Adding exchange reaction EX_m02136x with default bounds for boundary metabolite: m02136x.
# Adding exchange reaction EX_m02137x with default bounds for boundary metabolite: m02137x.
# Adding exchange reaction EX_m02139x with default bounds for boundary metabolite: m02139x.
# Adding exchange reaction EX_m02141x with default bounds for boundary metabolite: m02141x.
# Adding exchange reaction EX_m02145x with default bounds for boundary metabolite: m02145x.
# Adding exchange reaction EX_m02147x with default bounds for boundary metabolite: m02147x.
# Adding exchange reaction EX_m02150x with default bounds for boundary metabolite: m02150x.
# Adding exchange reaction EX_m02153x with default bounds for boundary metabolite: m02153x.
# Adding exchange reaction EX_m02155x with default bounds for boundary metabolite: m02155x.
# Adding exchange reaction EX_m02159x with default bounds for boundary metabolite: m02159x.
# Adding exchange reaction EX_m02161x with default bounds for boundary metabolite: m02161x.
# Adding exchange reaction EX_m02164x with default bounds for boundary metabolite: m02164x.
# Adding exchange reaction EX_m02167x with default bounds for boundary metabolite: m02167x.
# Adding exchange reaction EX_m02170x with default bounds for boundary metabolite: m02170x.
# Adding exchange reaction EX_m02171x with default bounds for boundary metabolite: m02171x.
# Adding exchange reaction EX_m02174x with default bounds for boundary metabolite: m02174x.
# Adding exchange reaction EX_m02182x with default bounds for boundary metabolite: m02182x.
# Adding exchange reaction EX_m02184x with default bounds for boundary metabolite: m02184x.
# Adding exchange reaction EX_m02191x with default bounds for boundary metabolite: m02191x.
# Adding exchange reaction EX_m02193x with default bounds for boundary metabolite: m02193x.
# Adding exchange reaction EX_m02198x with default bounds for boundary metabolite: m02198x.
# Adding exchange reaction EX_m02199x with default bounds for boundary metabolite: m02199x.
# Adding exchange reaction EX_m02200x with default bounds for boundary metabolite: m02200x.
# Adding exchange reaction EX_m02237x with default bounds for boundary metabolite: m02237x.
# Adding exchange reaction EX_m02278x with default bounds for boundary metabolite: m02278x.
# Adding exchange reaction EX_m02288x with default bounds for boundary metabolite: m02288x.
# Adding exchange reaction EX_m02303x with default bounds for boundary metabolite: m02303x.
# Adding exchange reaction EX_m02325x with default bounds for boundary metabolite: m02325x.
# Adding exchange reaction EX_m02331x with default bounds for boundary metabolite: m02331x.
# Adding exchange reaction EX_m02332x with default bounds for boundary metabolite: m02332x.
# Adding exchange reaction EX_m02337x with default bounds for boundary metabolite: m02337x.
# Adding exchange reaction EX_m02338x with default bounds for boundary metabolite: m02338x.
# Adding exchange reaction EX_m02348x with default bounds for boundary metabolite: m02348x.
# Adding exchange reaction EX_m02352x with default bounds for boundary metabolite: m02352x.
# Adding exchange reaction EX_m02353x with default bounds for boundary metabolite: m02353x.
# Adding exchange reaction EX_m02354x with default bounds for boundary metabolite: m02354x.
# Adding exchange reaction EX_m02357x with default bounds for boundary metabolite: m02357x.
# Adding exchange reaction EX_m02360x with default bounds for boundary metabolite: m02360x.
# Adding exchange reaction EX_m02362x with default bounds for boundary metabolite: m02362x.
# Adding exchange reaction EX_m02364x with default bounds for boundary metabolite: m02364x.
# Adding exchange reaction EX_m02366x with default bounds for boundary metabolite: m02366x.
# Adding exchange reaction EX_m02369x with default bounds for boundary metabolite: m02369x.
# Adding exchange reaction EX_m02370x with default bounds for boundary metabolite: m02370x.
# Adding exchange reaction EX_m02384x with default bounds for boundary metabolite: m02384x.
# Adding exchange reaction EX_m02386x with default bounds for boundary metabolite: m02386x.
# Adding exchange reaction EX_m02387x with default bounds for boundary metabolite: m02387x.
# Adding exchange reaction EX_m02389x with default bounds for boundary metabolite: m02389x.
# Adding exchange reaction EX_m02394x with default bounds for boundary metabolite: m02394x.
# Adding exchange reaction EX_m02403x with default bounds for boundary metabolite: m02403x.
# Adding exchange reaction EX_m02407x with default bounds for boundary metabolite: m02407x.
# Adding exchange reaction EX_m02414x with default bounds for boundary metabolite: m02414x.
# Adding exchange reaction EX_m02418x with default bounds for boundary metabolite: m02418x.
# Adding exchange reaction EX_m02426x with default bounds for boundary metabolite: m02426x.
# Adding exchange reaction EX_m02434x with default bounds for boundary metabolite: m02434x.
# Adding exchange reaction EX_m02440x with default bounds for boundary metabolite: m02440x.
# Adding exchange reaction EX_m02445x with default bounds for boundary metabolite: m02445x.
# Adding exchange reaction EX_m02450x with default bounds for boundary metabolite: m02450x.
# Adding exchange reaction EX_m02452x with default bounds for boundary metabolite: m02452x.
# Adding exchange reaction EX_m02453x with default bounds for boundary metabolite: m02453x.
# Adding exchange reaction EX_m02462x with default bounds for boundary metabolite: m02462x.
# Adding exchange reaction EX_m02470x with default bounds for boundary metabolite: m02470x.
# Adding exchange reaction EX_m02471x with default bounds for boundary metabolite: m02471x.
# Adding exchange reaction EX_m02475x with default bounds for boundary metabolite: m02475x.
# Adding exchange reaction EX_m02477x with default bounds for boundary metabolite: m02477x.
# Adding exchange reaction EX_m02510x with default bounds for boundary metabolite: m02510x.
# Adding exchange reaction EX_m02516x with default bounds for boundary metabolite: m02516x.
# Adding exchange reaction EX_m02519x with default bounds for boundary metabolite: m02519x.
# Adding exchange reaction EX_m02524x with default bounds for boundary metabolite: m02524x.
# Adding exchange reaction EX_m02527x with default bounds for boundary metabolite: m02527x.
# Adding exchange reaction EX_m02552x with default bounds for boundary metabolite: m02552x.
# Adding exchange reaction EX_m02554x with default bounds for boundary metabolite: m02554x.
# Adding exchange reaction EX_m02556x with default bounds for boundary metabolite: m02556x.
# Adding exchange reaction EX_m02560x with default bounds for boundary metabolite: m02560x.
# Adding exchange reaction EX_m02561x with default bounds for boundary metabolite: m02561x.
# Adding exchange reaction EX_m02578x with default bounds for boundary metabolite: m02578x.
# Adding exchange reaction EX_m02583x with default bounds for boundary metabolite: m02583x.
# Adding exchange reaction EX_m02586x with default bounds for boundary metabolite: m02586x.
# Adding exchange reaction EX_m02587x with default bounds for boundary metabolite: m02587x.
# Adding exchange reaction EX_m02588x with default bounds for boundary metabolite: m02588x.
# Adding exchange reaction EX_m02609x with default bounds for boundary metabolite: m02609x.
# Adding exchange reaction EX_m02614x with default bounds for boundary metabolite: m02614x.
# Adding exchange reaction EX_m02617x with default bounds for boundary metabolite: m02617x.
# Adding exchange reaction EX_m02620x with default bounds for boundary metabolite: m02620x.
# Adding exchange reaction EX_m02630x with default bounds for boundary metabolite: m02630x.
# Adding exchange reaction EX_m02631x with default bounds for boundary metabolite: m02631x.
# Adding exchange reaction EX_m02642x with default bounds for boundary metabolite: m02642x.
# Adding exchange reaction EX_m02653x with default bounds for boundary metabolite: m02653x.
# Adding exchange reaction EX_m02658x with default bounds for boundary metabolite: m02658x.
# Adding exchange reaction EX_m02659x with default bounds for boundary metabolite: m02659x.
# Adding exchange reaction EX_m02661x with default bounds for boundary metabolite: m02661x.
# Adding exchange reaction EX_m02672x with default bounds for boundary metabolite: m02672x.
# Adding exchange reaction EX_m02673x with default bounds for boundary metabolite: m02673x.
# Adding exchange reaction EX_m02680x with default bounds for boundary metabolite: m02680x.
# Adding exchange reaction EX_m02691x with default bounds for boundary metabolite: m02691x.
# Adding exchange reaction EX_m02692x with default bounds for boundary metabolite: m02692x.
# Adding exchange reaction EX_m02712x with default bounds for boundary metabolite: m02712x.
# Adding exchange reaction EX_m02722x with default bounds for boundary metabolite: m02722x.
# Adding exchange reaction EX_m02723x with default bounds for boundary metabolite: m02723x.
# Adding exchange reaction EX_m02724x with default bounds for boundary metabolite: m02724x.
# Adding exchange reaction EX_m02740x with default bounds for boundary metabolite: m02740x.
# Adding exchange reaction EX_m02744x with default bounds for boundary metabolite: m02744x.
# Adding exchange reaction EX_m02746x with default bounds for boundary metabolite: m02746x.
# Adding exchange reaction EX_m02751x with default bounds for boundary metabolite: m02751x.
# Adding exchange reaction EX_m02754x with default bounds for boundary metabolite: m02754x.
# Adding exchange reaction EX_m02769x with default bounds for boundary metabolite: m02769x.
# Adding exchange reaction EX_m02770x with default bounds for boundary metabolite: m02770x.
# Adding exchange reaction EX_m02772x with default bounds for boundary metabolite: m02772x.
# Adding exchange reaction EX_m02783x with default bounds for boundary metabolite: m02783x.
# Adding exchange reaction EX_m02785x with default bounds for boundary metabolite: m02785x.
# Adding exchange reaction EX_m02786x with default bounds for boundary metabolite: m02786x.
# Adding exchange reaction EX_m02789x with default bounds for boundary metabolite: m02789x.
# Adding exchange reaction EX_m02813x with default bounds for boundary metabolite: m02813x.
# Adding exchange reaction EX_m02814x with default bounds for boundary metabolite: m02814x.
# Adding exchange reaction EX_m02815x with default bounds for boundary metabolite: m02815x.
# Adding exchange reaction EX_m02817x with default bounds for boundary metabolite: m02817x.
# Adding exchange reaction EX_m02819x with default bounds for boundary metabolite: m02819x.
# Adding exchange reaction EX_m02833x with default bounds for boundary metabolite: m02833x.
# Adding exchange reaction EX_m02834x with default bounds for boundary metabolite: m02834x.
# Adding exchange reaction EX_m02836x with default bounds for boundary metabolite: m02836x.
# Adding exchange reaction EX_m02841x with default bounds for boundary metabolite: m02841x.
# Adding exchange reaction EX_m02842x with default bounds for boundary metabolite: m02842x.
# Adding exchange reaction EX_m02843x with default bounds for boundary metabolite: m02843x.
# Adding exchange reaction EX_m02880x with default bounds for boundary metabolite: m02880x.
# Adding exchange reaction EX_m02885x with default bounds for boundary metabolite: m02885x.
# Adding exchange reaction EX_m02896x with default bounds for boundary metabolite: m02896x.
# Adding exchange reaction EX_m02897x with default bounds for boundary metabolite: m02897x.
# Adding exchange reaction EX_m02902x with default bounds for boundary metabolite: m02902x.
# Adding exchange reaction EX_m02903x with default bounds for boundary metabolite: m02903x.
# Adding exchange reaction EX_m02907x with default bounds for boundary metabolite: m02907x.
# Adding exchange reaction EX_m02909x with default bounds for boundary metabolite: m02909x.
# Adding exchange reaction EX_m02924x with default bounds for boundary metabolite: m02924x.
# Adding exchange reaction EX_m02926x with default bounds for boundary metabolite: m02926x.
# Adding exchange reaction EX_m02928x with default bounds for boundary metabolite: m02928x.
# Adding exchange reaction EX_m02930x with default bounds for boundary metabolite: m02930x.
# Adding exchange reaction EX_m02931x with default bounds for boundary metabolite: m02931x.
# Adding exchange reaction EX_m02936x with default bounds for boundary metabolite: m02936x.
# Adding exchange reaction EX_m02937x with default bounds for boundary metabolite: m02937x.
# Adding exchange reaction EX_m02943x with default bounds for boundary metabolite: m02943x.
# Adding exchange reaction EX_m02945x with default bounds for boundary metabolite: m02945x.
# Adding exchange reaction EX_m02946x with default bounds for boundary metabolite: m02946x.
# Adding exchange reaction EX_m02949x with default bounds for boundary metabolite: m02949x.
# Adding exchange reaction EX_m02957x with default bounds for boundary metabolite: m02957x.
# Adding exchange reaction EX_m02961x with default bounds for boundary metabolite: m02961x.
# Adding exchange reaction EX_m02962x with default bounds for boundary metabolite: m02962x.
# Adding exchange reaction EX_m02963x with default bounds for boundary metabolite: m02963x.
# Adding exchange reaction EX_m02967x with default bounds for boundary metabolite: m02967x.
# Adding exchange reaction EX_m02968x with default bounds for boundary metabolite: m02968x.
# Adding exchange reaction EX_m02969x with default bounds for boundary metabolite: m02969x.
# Adding exchange reaction EX_m02980x with default bounds for boundary metabolite: m02980x.
# Adding exchange reaction EX_m02982x with default bounds for boundary metabolite: m02982x.
# Adding exchange reaction EX_m02983x with default bounds for boundary metabolite: m02983x.
# Adding exchange reaction EX_m02985x with default bounds for boundary metabolite: m02985x.
# Adding exchange reaction EX_m02986x with default bounds for boundary metabolite: m02986x.
# Adding exchange reaction EX_m02991x with default bounds for boundary metabolite: m02991x.
# Adding exchange reaction EX_m02993x with default bounds for boundary metabolite: m02993x.
# Adding exchange reaction EX_m02994x with default bounds for boundary metabolite: m02994x.
# Adding exchange reaction EX_m02996x with default bounds for boundary metabolite: m02996x.
# Adding exchange reaction EX_m02997x with default bounds for boundary metabolite: m02997x.
# Adding exchange reaction EX_m02998x with default bounds for boundary metabolite: m02998x.
# Adding exchange reaction EX_m03001x with default bounds for boundary metabolite: m03001x.
# Adding exchange reaction EX_m03039x with default bounds for boundary metabolite: m03039x.
# Adding exchange reaction EX_m03044x with default bounds for boundary metabolite: m03044x.
# Adding exchange reaction EX_m03052x with default bounds for boundary metabolite: m03052x.
# Adding exchange reaction EX_m03089x with default bounds for boundary metabolite: m03089x.
# Adding exchange reaction EX_m03096x with default bounds for boundary metabolite: m03096x.
# Adding exchange reaction EX_m03098x with default bounds for boundary metabolite: m03098x.
# Adding exchange reaction EX_m03100x with default bounds for boundary metabolite: m03100x.
# Adding exchange reaction EX_m03101x with default bounds for boundary metabolite: m03101x.
# Adding exchange reaction EX_m03106x with default bounds for boundary metabolite: m03106x.
# Adding exchange reaction EX_m03113x with default bounds for boundary metabolite: m03113x.
# Adding exchange reaction EX_m03114x with default bounds for boundary metabolite: m03114x.
# Adding exchange reaction EX_m03117x with default bounds for boundary metabolite: m03117x.
# Adding exchange reaction EX_m03118x with default bounds for boundary metabolite: m03118x.
# Adding exchange reaction EX_m03120x with default bounds for boundary metabolite: m03120x.
# Adding exchange reaction EX_m03121x with default bounds for boundary metabolite: m03121x.
# Adding exchange reaction EX_m03123x with default bounds for boundary metabolite: m03123x.
# Adding exchange reaction EX_m03130x with default bounds for boundary metabolite: m03130x.
# Adding exchange reaction EX_m03131x with default bounds for boundary metabolite: m03131x.
# Adding exchange reaction EX_m03134x with default bounds for boundary metabolite: m03134x.
# Adding exchange reaction EX_m03135x with default bounds for boundary metabolite: m03135x.
# Adding exchange reaction EX_m03138x with default bounds for boundary metabolite: m03138x.
# Adding exchange reaction EX_m03141x with default bounds for boundary metabolite: m03141x.
# Adding exchange reaction EX_m03142x with default bounds for boundary metabolite: m03142x.
# Adding exchange reaction EX_m03146x with default bounds for boundary metabolite: m03146x.
# Adding exchange reaction EX_m03147x with default bounds for boundary metabolite: m03147x.
# Adding exchange reaction EX_m03151x with default bounds for boundary metabolite: m03151x.
# Adding exchange reaction EX_m03154x with default bounds for boundary metabolite: m03154x.
# Adding exchange reaction EX_m03155x with default bounds for boundary metabolite: m03155x.
# Adding exchange reaction EX_m03157x with default bounds for boundary metabolite: m03157x.
# Adding exchange reaction EX_temp001x with default bounds for boundary metabolite: temp001x.
# Adding exchange reaction EX_m10000x with default bounds for boundary metabolite: m10000x.
# Adding exchange reaction EX_m10001x with default bounds for boundary metabolite: m10001x.
# Adding exchange reaction EX_m10002x with default bounds for boundary metabolite: m10002x.
# Adding exchange reaction EX_m10003x with default bounds for boundary metabolite: m10003x.
# Adding exchange reaction EX_m01451x with default bounds for boundary metabolite: m01451x.
# Adding exchange reaction EX_m00003x with default bounds for boundary metabolite: m00003x.
# Adding exchange reaction EX_m00008x with default bounds for boundary metabolite: m00008x.
# Adding exchange reaction EX_m00010x with default bounds for boundary metabolite: m00010x.
# Adding exchange reaction EX_m00017x with default bounds for boundary metabolite: m00017x.
# Adding exchange reaction EX_m00019x with default bounds for boundary metabolite: m00019x.
# Adding exchange reaction EX_m00021x with default bounds for boundary metabolite: m00021x.
# Adding exchange reaction EX_m00028x with default bounds for boundary metabolite: m00028x.
# Adding exchange reaction EX_m00094x with default bounds for boundary metabolite: m00094x.
# Adding exchange reaction EX_m00104x with default bounds for boundary metabolite: m00104x.
# Adding exchange reaction EX_m00105x with default bounds for boundary metabolite: m00105x.
# Adding exchange reaction EX_m00111x with default bounds for boundary metabolite: m00111x.
# Adding exchange reaction EX_m00114x with default bounds for boundary metabolite: m00114x.
# Adding exchange reaction EX_m00115x with default bounds for boundary metabolite: m00115x.
# Adding exchange reaction EX_m00117x with default bounds for boundary metabolite: m00117x.
# Adding exchange reaction EX_CE2516_x with default bounds for boundary metabolite: CE2516_x.
# Adding exchange reaction EX_m00126x with default bounds for boundary metabolite: m00126x.
# Adding exchange reaction EX_m00128x with default bounds for boundary metabolite: m00128x.
# Adding exchange reaction EX_m00132x with default bounds for boundary metabolite: m00132x.
# Adding exchange reaction EX_m00135x with default bounds for boundary metabolite: m00135x.
# Adding exchange reaction EX_m00167x with default bounds for boundary metabolite: m00167x.
# Adding exchange reaction EX_m00169x with default bounds for boundary metabolite: m00169x.
# Adding exchange reaction EX_glyc_S_x with default bounds for boundary metabolite: glyc_S_x.
# Adding exchange reaction EX_hexdtr_x with default bounds for boundary metabolite: hexdtr_x.
# Adding exchange reaction EX_1glyc_hs_x with default bounds for boundary metabolite: 1glyc_hs_x.
# Adding exchange reaction EX_1ohmdz_x with default bounds for boundary metabolite: 1ohmdz_x.
# Adding exchange reaction EX_1hmdgluc_x with default bounds for boundary metabolite: 1hmdgluc_x.
# Adding exchange reaction EX_12dgr120_x with default bounds for boundary metabolite: 12dgr120_x.
# Adding exchange reaction EX_m00231x with default bounds for boundary metabolite: m00231x.
# Adding exchange reaction EX_m00240x with default bounds for boundary metabolite: m00240x.
# Adding exchange reaction EX_m00241x with default bounds for boundary metabolite: m00241x.
# Adding exchange reaction EX_m00234x with default bounds for boundary metabolite: m00234x.
# Adding exchange reaction EX_m00248x with default bounds for boundary metabolite: m00248x.
# Adding exchange reaction EX_14hmdz_x with default bounds for boundary metabolite: 14hmdz_x.
# Adding exchange reaction EX_magarachi_hs_x with default bounds for boundary metabolite: magarachi_hs_x.
# Adding exchange reaction EX_pcholar_hs_x with default bounds for boundary metabolite: pcholar_hs_x.
# Adding exchange reaction EX_pear_hs_x with default bounds for boundary metabolite: pear_hs_x.
# Adding exchange reaction EX_pailar_hs_x with default bounds for boundary metabolite: pailar_hs_x.
# Adding exchange reaction EX_pe12_hs_x with default bounds for boundary metabolite: pe12_hs_x.
# Adding exchange reaction EX_pcholn203_hs_x with default bounds for boundary metabolite: pcholn203_hs_x.
# Adding exchange reaction EX_pedh203_hs_x with default bounds for boundary metabolite: pedh203_hs_x.
# Adding exchange reaction EX_pcholdoc_hs_x with default bounds for boundary metabolite: pcholdoc_hs_x.
# Adding exchange reaction EX_pe226_hs_x with default bounds for boundary metabolite: pe226_hs_x.
# Adding exchange reaction EX_pcholn226_hs_x with default bounds for boundary metabolite: pcholn226_hs_x.
# Adding exchange reaction EX_pcholn2254_hs_x with default bounds for boundary metabolite: pcholn2254_hs_x.
# Adding exchange reaction EX_pcholn225_hs_x with default bounds for boundary metabolite: pcholn225_hs_x.
# Adding exchange reaction EX_pe224_hs_x with default bounds for boundary metabolite: pe224_hs_x.
# Adding exchange reaction EX_pcholn224_hs_x with default bounds for boundary metabolite: pcholn224_hs_x.
# Adding exchange reaction EX_pcholeic_hs_x with default bounds for boundary metabolite: pcholeic_hs_x.
# Adding exchange reaction EX_pcholn205_hs_x with default bounds for boundary metabolite: pcholn205_hs_x.
# Adding exchange reaction EX_pcholn204_hs_x with default bounds for boundary metabolite: pcholn204_hs_x.
# Adding exchange reaction EX_pcholet_hs_x with default bounds for boundary metabolite: pcholet_hs_x.
# Adding exchange reaction EX_pe203_hs_x with default bounds for boundary metabolite: pe203_hs_x.
# Adding exchange reaction EX_pcholn201_hs_x with default bounds for boundary metabolite: pcholn201_hs_x.
# Adding exchange reaction EX_xolest183_hs_x with default bounds for boundary metabolite: xolest183_hs_x.
# Adding exchange reaction EX_pcholhep_hs_x with default bounds for boundary metabolite: pcholhep_hs_x.
# Adding exchange reaction EX_pe17_hs_x with default bounds for boundary metabolite: pe17_hs_x.
# Adding exchange reaction EX_pe161_hs_x with default bounds for boundary metabolite: pe161_hs_x.
# Adding exchange reaction EX_pcholn24_hs_x with default bounds for boundary metabolite: pcholn24_hs_x.
# Adding exchange reaction EX_xolest182_hs_x with default bounds for boundary metabolite: xolest182_hs_x.
# Adding exchange reaction EX_maglinl_hs_x with default bounds for boundary metabolite: maglinl_hs_x.
# Adding exchange reaction EX_pchollinl_hs_x with default bounds for boundary metabolite: pchollinl_hs_x.
# Adding exchange reaction EX_pelinl_hs_x with default bounds for boundary metabolite: pelinl_hs_x.
# Adding exchange reaction EX_pcholmyr_hs_x with default bounds for boundary metabolite: pcholmyr_hs_x.
# Adding exchange reaction EX_pe14_hs_x with default bounds for boundary metabolite: pe14_hs_x.
# Adding exchange reaction EX_pcholn19_hs_x with default bounds for boundary metabolite: pcholn19_hs_x.
# Adding exchange reaction EX_pcholn1836_hs_x with default bounds for boundary metabolite: pcholn1836_hs_x.
# Adding exchange reaction EX_pcholn183_hs_x with default bounds for boundary metabolite: pcholn183_hs_x.
# Adding exchange reaction EX_magole_hs_x with default bounds for boundary metabolite: magole_hs_x.
# Adding exchange reaction EX_pcholole_hs_x with default bounds for boundary metabolite: pcholole_hs_x.
# ...
# Adding exchange reaction EX_nfdlac_x with default bounds for boundary metabolite: nfdlac_x.
# Adding exchange reaction EX_m02333x with default bounds for boundary metabolite: m02333x.
# Adding exchange reaction EX_m02336x with default bounds for boundary metabolite: m02336x.
# Adding exchange reaction EX_m02343x with default bounds for boundary metabolite: m02343x.
# Adding exchange reaction EX_m02344x with default bounds for boundary metabolite: m02344x.
# Adding exchange reaction EX_m02365x with default bounds for boundary metabolite: m02365x.
# Adding exchange reaction EX_m02385x with default bounds for boundary metabolite: m02385x.
# Adding exchange reaction EX_m02388x with default bounds for boundary metabolite: m02388x.
# Adding exchange reaction EX_m02393x with default bounds for boundary metabolite: m02393x.
# Adding exchange reaction EX_m02395x with default bounds for boundary metabolite: m02395x.
# Adding exchange reaction EX_m02396x with default bounds for boundary metabolite: m02396x.
# Adding exchange reaction EX_m02402x with default bounds for boundary metabolite: m02402x.
# Adding exchange reaction EX_lvst_x with default bounds for boundary metabolite: lvst_x.
# Adding exchange reaction EX_lvstacid_x with default bounds for boundary metabolite: lvstacid_x.
# Adding exchange reaction EX_m02429x with default bounds for boundary metabolite: m02429x.
# Adding exchange reaction EX_m02439x with default bounds for boundary metabolite: m02439x.
# Adding exchange reaction EX_m02441x with default bounds for boundary metabolite: m02441x.
# Adding exchange reaction EX_m02444x with default bounds for boundary metabolite: m02444x.
# Adding exchange reaction EX_m02446x with default bounds for boundary metabolite: m02446x.
# Adding exchange reaction EX_m02447x with default bounds for boundary metabolite: m02447x.
# Adding exchange reaction EX_m02448x with default bounds for boundary metabolite: m02448x.
# Adding exchange reaction EX_m02449x with default bounds for boundary metabolite: m02449x.
# Adding exchange reaction EX_m02451x with default bounds for boundary metabolite: m02451x.
# Adding exchange reaction EX_m02456x with default bounds for boundary metabolite: m02456x.
# Adding exchange reaction EX_m02457x with default bounds for boundary metabolite: m02457x.
# Adding exchange reaction EX_m02460x with default bounds for boundary metabolite: m02460x.
# Adding exchange reaction EX_m02467x with default bounds for boundary metabolite: m02467x.
# Adding exchange reaction EX_m02473x with default bounds for boundary metabolite: m02473x.
# Adding exchange reaction EX_m02479x with default bounds for boundary metabolite: m02479x.
# Adding exchange reaction EX_m02494x with default bounds for boundary metabolite: m02494x.
# Adding exchange reaction EX_m02563x with default bounds for boundary metabolite: m02563x.
# Adding exchange reaction EX_m02562x with default bounds for boundary metabolite: m02562x.
# Adding exchange reaction EX_m02564x with default bounds for boundary metabolite: m02564x.
# Adding exchange reaction EX_m02570x with default bounds for boundary metabolite: m02570x.
# Adding exchange reaction EX_m02569x with default bounds for boundary metabolite: m02569x.
# Adding exchange reaction EX_m02585x with default bounds for boundary metabolite: m02585x.
# Adding exchange reaction EX_m02591x with default bounds for boundary metabolite: m02591x.
# Adding exchange reaction EX_m02613x with default bounds for boundary metabolite: m02613x.
# Adding exchange reaction EX_m02622x with default bounds for boundary metabolite: m02622x.
# Adding exchange reaction EX_m02639x with default bounds for boundary metabolite: m02639x.
# Adding exchange reaction EX_m02646x with default bounds for boundary metabolite: m02646x.
# Adding exchange reaction EX_m02648x with default bounds for boundary metabolite: m02648x.
# Adding exchange reaction EX_m02660x with default bounds for boundary metabolite: m02660x.
# Adding exchange reaction EX_oxyp_x with default bounds for boundary metabolite: oxyp_x.
# Adding exchange reaction EX_oxy1rb_x with default bounds for boundary metabolite: oxy1rb_x.
# Adding exchange reaction EX_oxy7rb_x with default bounds for boundary metabolite: oxy7rb_x.
# Adding exchange reaction EX_m02674x with default bounds for boundary metabolite: m02674x.
# Adding exchange reaction EX_m02675x with default bounds for boundary metabolite: m02675x.
# Adding exchange reaction EX_m02676x with default bounds for boundary metabolite: m02676x.
# Adding exchange reaction EX_m02679x with default bounds for boundary metabolite: m02679x.
# Adding exchange reaction EX_m02690x with default bounds for boundary metabolite: m02690x.
# Adding exchange reaction EX_m02714x with default bounds for boundary metabolite: m02714x.
# Adding exchange reaction EX_m02720x with default bounds for boundary metabolite: m02720x.
# Adding exchange reaction EX_m02725x with default bounds for boundary metabolite: m02725x.
# Adding exchange reaction EX_m02733x with default bounds for boundary metabolite: m02733x.
# Adding exchange reaction EX_m02738x with default bounds for boundary metabolite: m02738x.
# Adding exchange reaction EX_m02741x with default bounds for boundary metabolite: m02741x.
# Adding exchange reaction EX_m02745x with default bounds for boundary metabolite: m02745x.
# Adding exchange reaction EX_m02752x with default bounds for boundary metabolite: m02752x.
# Adding exchange reaction EX_ptvst_x with default bounds for boundary metabolite: ptvst_x.
# Adding exchange reaction EX_ptvstm13_x with default bounds for boundary metabolite: ptvstm13_x.
# Adding exchange reaction EX_ptvstm3_x with default bounds for boundary metabolite: ptvstm3_x.
# Adding exchange reaction EX_ptvstlac_x with default bounds for boundary metabolite: ptvstlac_x.
# Adding exchange reaction EX_m02753x with default bounds for boundary metabolite: m02753x.
# Adding exchange reaction EX_m02756x with default bounds for boundary metabolite: m02756x.
# Adding exchange reaction EX_pvs_x with default bounds for boundary metabolite: pvs_x.
# Adding exchange reaction EX_pvsgluc_x with default bounds for boundary metabolite: pvsgluc_x.
# Adding exchange reaction EX_m02763x with default bounds for boundary metabolite: m02763x.
# Adding exchange reaction EX_m02762x with default bounds for boundary metabolite: m02762x.
# Adding exchange reaction EX_m02766x with default bounds for boundary metabolite: m02766x.
# Adding exchange reaction EX_m02771x with default bounds for boundary metabolite: m02771x.
# Adding exchange reaction EX_m02776x with default bounds for boundary metabolite: m02776x.
# Adding exchange reaction EX_m02777x with default bounds for boundary metabolite: m02777x.
# Adding exchange reaction EX_m02778x with default bounds for boundary metabolite: m02778x.
# Adding exchange reaction EX_m02779x with default bounds for boundary metabolite: m02779x.
# Adding exchange reaction EX_m02780x with default bounds for boundary metabolite: m02780x.
# Adding exchange reaction EX_m02781x with default bounds for boundary metabolite: m02781x.
# Adding exchange reaction EX_m02782x with default bounds for boundary metabolite: m02782x.
# Adding exchange reaction EX_m02784x with default bounds for boundary metabolite: m02784x.
# Adding exchange reaction EX_m02787x with default bounds for boundary metabolite: m02787x.
# Adding exchange reaction EX_m02788x with default bounds for boundary metabolite: m02788x.
# Adding exchange reaction EX_m02790x with default bounds for boundary metabolite: m02790x.
# Adding exchange reaction EX_m02792x with default bounds for boundary metabolite: m02792x.
# Adding exchange reaction EX_m02794x with default bounds for boundary metabolite: m02794x.
# Adding exchange reaction EX_m02795x with default bounds for boundary metabolite: m02795x.
# Adding exchange reaction EX_m02796x with default bounds for boundary metabolite: m02796x.
# Adding exchange reaction EX_m02802x with default bounds for boundary metabolite: m02802x.
# Adding exchange reaction EX_m02803x with default bounds for boundary metabolite: m02803x.
# Adding exchange reaction EX_m02805x with default bounds for boundary metabolite: m02805x.
# Adding exchange reaction EX_m02812x with default bounds for boundary metabolite: m02812x.
# Adding exchange reaction EX_m02821x with default bounds for boundary metabolite: m02821x.
# Adding exchange reaction EX_m02822x with default bounds for boundary metabolite: m02822x.
# Adding exchange reaction EX_m02823x with default bounds for boundary metabolite: m02823x.
# Adding exchange reaction EX_m02832x with default bounds for boundary metabolite: m02832x.
# Adding exchange reaction EX_m02837x with default bounds for boundary metabolite: m02837x.
# Adding exchange reaction EX_m02839x with default bounds for boundary metabolite: m02839x.
# Adding exchange reaction EX_rsv_x with default bounds for boundary metabolite: rsv_x.
# Adding exchange reaction EX_rsvlac_x with default bounds for boundary metabolite: rsvlac_x.
# Adding exchange reaction EX_m02868x with default bounds for boundary metabolite: m02868x.
# Adding exchange reaction EX_m02875x with default bounds for boundary metabolite: m02875x.
# Adding exchange reaction EX_m02891x with default bounds for boundary metabolite: m02891x.
# Adding exchange reaction EX_smvacid_x with default bounds for boundary metabolite: smvacid_x.
# Adding exchange reaction EX_smv_x with default bounds for boundary metabolite: smv_x.
# Adding exchange reaction EX_m02912x with default bounds for boundary metabolite: m02912x.
# Adding exchange reaction EX_m02914x with default bounds for boundary metabolite: m02914x.
# Adding exchange reaction EX_m02923x with default bounds for boundary metabolite: m02923x.
# Adding exchange reaction EX_m02920x with default bounds for boundary metabolite: m02920x.
# Adding exchange reaction EX_m02921x with default bounds for boundary metabolite: m02921x.
# Adding exchange reaction EX_m02922x with default bounds for boundary metabolite: m02922x.
# Adding exchange reaction EX_m02925x with default bounds for boundary metabolite: m02925x.
# Adding exchange reaction EX_m02927x with default bounds for boundary metabolite: m02927x.
# Adding exchange reaction EX_m02929x with default bounds for boundary metabolite: m02929x.
# Adding exchange reaction EX_m02933x with default bounds for boundary metabolite: m02933x.
# Adding exchange reaction EX_m02938x with default bounds for boundary metabolite: m02938x.
# Adding exchange reaction EX_m02939x with default bounds for boundary metabolite: m02939x.
# Adding exchange reaction EX_m02940x with default bounds for boundary metabolite: m02940x.
# Adding exchange reaction EX_m02942x with default bounds for boundary metabolite: m02942x.
# Adding exchange reaction EX_m02950x with default bounds for boundary metabolite: m02950x.
# Adding exchange reaction EX_m02951x with default bounds for boundary metabolite: m02951x.
# Adding exchange reaction EX_m02952x with default bounds for boundary metabolite: m02952x.
# Adding exchange reaction EX_stacmp_x with default bounds for boundary metabolite: stacmp_x.
# Adding exchange reaction EX_s3meacmp_x with default bounds for boundary metabolite: s3meacmp_x.
# Adding exchange reaction EX_sulpacmp_x with default bounds for boundary metabolite: sulpacmp_x.
# Adding exchange reaction EX_tauribup_S_x with default bounds for boundary metabolite: tauribup_S_x.
# Adding exchange reaction EX_m02964x with default bounds for boundary metabolite: m02964x.
# Adding exchange reaction EX_m02965x with default bounds for boundary metabolite: m02965x.
# Adding exchange reaction EX_m02966x with default bounds for boundary metabolite: m02966x.
# Adding exchange reaction EX_m02974x with default bounds for boundary metabolite: m02974x.
# Adding exchange reaction EX_m02978x with default bounds for boundary metabolite: m02978x.
# Adding exchange reaction EX_tsacmgluc_x with default bounds for boundary metabolite: tsacmgluc_x.
# Adding exchange reaction EX_tsacmsul_x with default bounds for boundary metabolite: tsacmsul_x.
# Adding exchange reaction EX_thrfvs_x with default bounds for boundary metabolite: thrfvs_x.
# Adding exchange reaction EX_m02992x with default bounds for boundary metabolite: m02992x.
# Adding exchange reaction EX_m02995x with default bounds for boundary metabolite: m02995x.
# Adding exchange reaction EX_m03037x with default bounds for boundary metabolite: m03037x.
# Adding exchange reaction EX_tlacfvs_x with default bounds for boundary metabolite: tlacfvs_x.
# Adding exchange reaction EX_m03045x with default bounds for boundary metabolite: m03045x.
# Adding exchange reaction EX_m03051x with default bounds for boundary metabolite: m03051x.
# Adding exchange reaction EX_tripvs_x with default bounds for boundary metabolite: tripvs_x.
# Adding exchange reaction EX_m03088x with default bounds for boundary metabolite: m03088x.
# Adding exchange reaction EX_m03099x with default bounds for boundary metabolite: m03099x.
# Adding exchange reaction EX_m03102x with default bounds for boundary metabolite: m03102x.
# Adding exchange reaction EX_m03103x with default bounds for boundary metabolite: m03103x.
# Adding exchange reaction EX_m03124x with default bounds for boundary metabolite: m03124x.
# Adding exchange reaction EX_m03125x with default bounds for boundary metabolite: m03125x.
# Adding exchange reaction EX_m03127x with default bounds for boundary metabolite: m03127x.
# Adding exchange reaction EX_m03129x with default bounds for boundary metabolite: m03129x.
# Adding exchange reaction EX_m03136x with default bounds for boundary metabolite: m03136x.
# Adding exchange reaction EX_m03148x with default bounds for boundary metabolite: m03148x.
# Adding exchange reaction EX_m03149x with default bounds for boundary metabolite: m03149x.
# Adding exchange reaction EX_m03150x with default bounds for boundary metabolite: m03150x.
# Adding exchange reaction EX_m03153x with default bounds for boundary metabolite: m03153x.
# Adding exchange reaction EX_m00591x with default bounds for boundary metabolite: m00591x.
# Adding exchange reaction EX_m01435x with default bounds for boundary metabolite: m01435x.
# Adding exchange reaction EX_m02328x with default bounds for boundary metabolite: m02328x.
# Adding exchange reaction EX_chylo_hs_x with default bounds for boundary metabolite: chylo_hs_x.
# Adding exchange reaction EX_m10005x with default bounds for boundary metabolite: m10005x.
# Adding exchange reaction EX_m10006x with default bounds for boundary metabolite: m10006x.
# Adding exchange reaction EX_m10011x with default bounds for boundary metabolite: m10011x.
# Adding exchange reaction EX_m00235x with default bounds for boundary metabolite: m00235x.
# Adding exchange reaction EX_m02838x with default bounds for boundary metabolite: m02838x.
# Adding exchange reaction EX_m10021x with default bounds for boundary metabolite: m10021x.
# Adding exchange reaction EX_m10022x with default bounds for boundary metabolite: m10022x.
# Adding exchange reaction EX_m10023x with default bounds for boundary metabolite: m10023x.
# Adding exchange reaction EX_m10024x with default bounds for boundary metabolite: m10024x.
# Adding exchange reaction EX_m10025x with default bounds for boundary metabolite: m10025x.
# Adding exchange reaction EX_m10026x with default bounds for boundary metabolite: m10026x.
# Adding exchange reaction EX_m10027x with default bounds for boundary metabolite: m10027x.
# Adding exchange reaction EX_m10028x with default bounds for boundary metabolite: m10028x.
# Adding exchange reaction EX_m10029x with default bounds for boundary metabolite: m10029x.
# Adding exchange reaction EX_m10030x with default bounds for boundary metabolite: m10030x.
# Adding exchange reaction EX_m10031x with default bounds for boundary metabolite: m10031x.
# Adding exchange reaction EX_m10032x with default bounds for boundary metabolite: m10032x.
# Adding exchange reaction EX_m10033x with default bounds for boundary metabolite: m10033x.
# Adding exchange reaction EX_m10034x with default bounds for boundary metabolite: m10034x.
# Adding exchange reaction EX_m10041x with default bounds for boundary metabolite: m10041x.
# <Model  at 0x7fbf4184f8d0>

# %%
model2.metabolites[99]
# Out:
# <Metabolite m00043c at 0x7fbf4352fef0>

# %%
dir(model2.metabolites[99])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotation',
#  '_bound',
#  '_id',
#  '_model',
#  '_reaction',
#  '_repr_html_',
#  '_set_id_with_model',
#  'annotation',
#  'charge',
#  'compartment',
#  'constraint',
#  'copy',
#  'elements',
#  'formula',
#  'formula_weight',
#  'id',
#  'model',
#  'name',
#  'notes',
#  'reactions',
#  'remove_from_model',
#  'shadow_price',
#  'summary',
#  'y']

# %%
def at_metabolite2compound(M):
    # convert cobra Metabolite to metDataModel Compound
    Cpd = Compound()
    Cpd.src_id = M.id
    Cpd.id = M.id           #[2:8]
    Cpd.name = M.name
    Cpd.charge = M.charge
    Cpd.charged_formula = M.formula
    Cpd.db_ids = M.annotation
    return Cpd

[at_metabolite2compound(model2.metabolites[199]).id,
 at_metabolite2compound(model2.metabolites[99]).src_id,
 at_metabolite2compound(model2.metabolites[99]).charged_formula,
 at_metabolite2compound(model2.metabolites[99]).db_ids,
]
# Out:
# ['m00103c', 'm00043c', 'C41H68N7O17P3S', {'sbo': 'SBO:0000247'}]

# %%
# list of Compounds
atCpds = []
anno2 = {}
for M in model2.metabolites:
    anno2[M.id] = M.annotation
    atCpds.append(at_metabolite2compound(M))
    
print("total, ", len(atCpds), len(anno2))

unique = set([C.id for C in atCpds])
formula = set([C.charged_formula for C in atCpds if C.charged_formula])
# a little tricker to test on dictionaries
annotation = [v for v in anno2.values() if v]

print("real, ", len(unique), len(formula), len(annotation))
# Out:
# total,  10073 10073
# real,  10073 2680 10073

# %%
list(unique)[:9]
# Out:
# ['asnphecys_c',
#  'm03155s',
#  'pcholar_hs_c',
#  'm01819x',
#  'c12dc_p',
#  'm00333m',
#  'm02349s',
#  'm00630m',
#  '35dhpvs_s']

# %% [markdown]
# **The ATLA format is not all compatible with cobra**
#
# Do something else for now:

# %%
#
# Will check the JSON data in the repo
# shuzhao@canyon:~/projects/Azimuth/model_porting$ ls Human-GEM/data/annotation/
# humanGEMMetAssoc.JSON  humanGEMRxnAssoc.JSON

import json
jm = json.load(open('Human-GEM/data/annotation/humanGEMMetAssoc.JSON'))

print(jm.keys())
# Out:
# dict_keys(['mets', 'metsNoComp', 'metBiGGID', 'metKEGGID', 'metHMDBID', 'metChEBIID', 'metPubChemID', 'metLipidMapsID', 'metEHMNID', 'metHepatoNET1ID', 'metRecon3DID', 'metMetaNetXID'])

# %%
for k,v in jm.items(): 
    print( v[:5] )
# Out:
# ['m00001c', 'm00001s', 'm00002c', 'm00002s', 'm00003c']
# ['m00001', 'm00001', 'm00002', 'm00002', 'm00003']
# ['carveol', 'carveol', 'appnn', 'appnn', '']
# ['C00964', 'C00964', 'C09880', 'C09880', '']
# ['', '', 'HMDB06525', 'HMDB06525', '']
# ['CHEBI:15389', 'CHEBI:15389', 'CHEBI:36740', 'CHEBI:36740', '']
# ['', '', '6654', '6654', '']
# ['', '', '', '', 'LMFA01030283']
# ['', '', '', '', '']
# ['', '', '', '', '']
# ['carveol', 'carveol', 'appnn', 'appnn', 'M00003']
# ['MNXM45735', 'MNXM45735', 'MNXM163755', 'MNXM163755', 'MNXM150165; MNXM27815']

# %%
# How many unique IDs in each?
for k,v in jm.items(): 
    print(k, len(set(v)))
# Out:
# mets 10138
# metsNoComp 4168
# metBiGGID 2347
# metKEGGID 1647
# metHMDBID 713
# metChEBIID 1247
# metPubChemID 1382
# metLipidMapsID 487
# metEHMNID 712
# metHepatoNET1ID 773
# metRecon3DID 5089
# metMetaNetXID 2972

# %%
# there is 4168 metsNoComp

# check HMDB or PubChem
HP = {}
for ii in range(10138):
    HP[jm['metsNoComp'][ii]] = jm['metHMDBID'][ii] or jm['metPubChemID'][ii]
    
print(len(HP))
print(len(set([x for x in HP.values() if x])))
# Out:
# 4168
# 1411

# %% [markdown]
# ### Numbers in ATLAS
#
# len(unique) 4168
#
# len(formula) 2680
#
# len(annotation) = 1411 # HMDB or PubChem

# %% [markdown]
# ## E. coli
#
# http://bigg.ucsd.edu/models/
#
# Downloads last updated Oct 31, 2019

# %%
ecoli = 'EColi-iJO1366/iJO1366.xml'

model3 = cobra.io.read_sbml_model(ecoli)

# %%
model3
# Out:
# <Model iJO1366 at 0x7fbf384ab128>

# %%
model3.metabolites[99]
# Out:
# <Metabolite 2agpe181_c at 0x7fbf38565f28>

# %%
def metabolite3compound(M):
    # convert cobra Metabolite to metDataModel Compound
    Cpd = Compound()
    Cpd.src_id = M.id
    Cpd.id = M.id.split("_")[0]
    Cpd.name = M.name
    Cpd.charge = M.charge
    Cpd.charged_formula = M.formula
    Cpd.db_ids = M.annotation
    return Cpd

[metabolite3compound(model3.metabolites[99]).id,
 metabolite3compound(model3.metabolites[99]).src_id,
 metabolite3compound(model3.metabolites[99]).charged_formula,
 metabolite3compound(model3.metabolites[99]).db_ids,
]
# Out:
# ['2agpe181',
#  '2agpe181_c',
#  'C23H46NO7P1',
#  {'sbo': 'SBO:0000247',
#   'bigg.metabolite': '2agpe181',
#   'metanetx.chemical': 'MNXM3449'}]

# %%
# list of Compounds
myCpds3 = []
anno3 = {}
for M in model3.metabolites:
    anno3[M.id.split("_")[0]] = M.annotation
    myCpds3.append(metabolite3compound(M))
    
print("total, ", len(myCpds3), len(anno3))

unique = set([C.id for C in myCpds3])
formula = set([C.charged_formula for C in myCpds3 if C.charged_formula])
# a little tricker to test on dictionaries
annotation = [v for v in anno3.values() if 'metanetx' in str(v)]

print("real, ", len(unique), len(formula), len(annotation))
# Out:
# total,  1805 1100
# real,  1100 911 1100

# %% [markdown]
# ### Numbers in E. coli iJO1366
#
# len(unique) 1100
# len(formula) 911
# len(annotation) = 1100 ?

# %% [markdown]
# ## WormJam model

# %%
worm = 'worm/WormJam-GEM-20190101_L3.xml'

model4 = cobra.io.read_sbml_model(worm)
# Out:
# '' is not a valid SBML 'SId'.
# No objective in listOfObjectives
# No objective coefficients in model. Unclear what should be optimized

# %%
model4
# Out:
# <Model  at 0x7fbf317d02b0>

# %%
model4.metabolites[9]
# Out:
# <Metabolite g3m8masn_c at 0x7fbf38f20240>

# %%
metabolites4 = [M.id for M in model4.metabolites]
print(len(metabolites4))

metabolites4 = set([x.split('_')[0] for x in metabolites4])
print(len(metabolites4))
# Out:
# 2834
# 1271

# %% [markdown]
# ### Numbers in WormJam
#
# len(unique) 1271
#
# formula and annotation yet unclear
#
# needed to pull from elsewhere

# %% [markdown]
# ### Numbers in Drosophila
#
#
# https://www.nature.com/articles/s41598-019-53532-4
#
# Schönborn, J.W., Jehrke, L., Mettler-Altmann, T. et al. FlySilico: Flux balance modeling of Drosophila larval growth and resource allocation. Sci Rep 9, 17156 (2019). https://doi.org/10.1038/s41598-019-53532-4
#
# This is a curated model, all metabolites having public IDs.
#
# number of unique metabolites = 203

# %%
fly = 'Drosophia/41598_2019_53532_MOESM2_ESM.xls'
xlsxData = xlrd.open_workbook(fly)
sheets = xlsxData.sheets()
for x in sheets: print(x.name)
# Out:
# Title page
# reactions
# metabolites

# %%
for ii in range(5):
    print(sheets[2].row_values(ii))
# Out:
# ['Abbreviation', 'officialname', 'formula(neutral)', 'formula', 'Charge', 'Compartment', 'KEGG ID', 'PubChem ID', 'ChEBI ID', 'InChI string', 'Smiles', 'HMDB', 'Notes']
# ['13dpg[c]', '3-Phospho-D-glyceroyl phosphate', 'C3H8O10P2', 'C3H4O10P2', -4.0, 'c', 'C00236', 3535.0, 16001.0, '1S/C3H8O10P2/c4-2(1-12-14(6,7)8)3(5)13-15(9,10)11/h2,4H,1H2,(H2,6,7,8)(H2,9,10,11)/t2-/m1/s1', 'O[C@H](COP(O)(O)=O)C(=O)OP(O)(O)=O', '', '']
# ['2pg[c]', 'D-Glycerate 2-phosphate', 'C3H7O7P', 'C3H4O7P', -3.0, 'c', 'C00631', 3904.0, 17835.0, '1S/C3H7O7P/c4-1-2(3(5)6)10-11(7,8)9/h2,4H,1H2,(H,5,6)(H2,7,8,9)/t2-/m1/s1', 'OC[C@@H](OP(O)(O)=O)C(O)=O', 'HMDB03391', '']
# ['3pg[c]', '3-Phospho-D-glycerate', 'C3H7O7P', 'C3H4O7P', -3.0, 'c', 'C00197', 3497.0, 17794.0, '1S/C3H7O7P/c4-2(3(5)6)1-10-11(7,8)9/h2,4H,1H2,(H,5,6)(H2,7,8,9)/p-3/t2-/m1/s1', 'C(OP(=O)([O-])[O-])C(O)C(=O)[O-]', '', '']
# ['6pgc[c]', '6-Phospho-D-gluconate', 'C6H13O10P', 'C6H10O10P', -3.0, 'c', 'C00345', 3638.0, 48928.0, '1S/C6H13O10P/c7-2(1-16-17(13,14)15)3(8)4(9)5(10)6(11)12/h2-5,7-10H,1H2,(H,11,12)(H2,13,14,15)/t2-,3-,4+,5-/m1/s1', 'O[C@H](COP(O)(O)=O)[C@@H](O)[C@H](O)[C@@H](O)C(O)=O', 'HMDB0001316', '']

# %%
fly_m = [sheets[2].row_values(ii)[0] for ii in range(1, sheets[2].nrows)]

fly_m_unique = set([x.split("[")[0] for x in fly_m])

print( len(fly_m), len(fly_m_unique ))
# Out:
# 293 203

# %% [markdown]
# **I needed the above information to make some quick figures.**
#
# Now getting to the export of models to our own format.
#
# Use RECON3D as example.
# Continued on a separate notebook - metabolicModel_RECON3D_20210510.json.
